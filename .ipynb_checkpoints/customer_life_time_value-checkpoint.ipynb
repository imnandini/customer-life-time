# %% [markdown]
# #### Problem Statement :
# To predict the Customer life time value for an auto insurance company based on different quantitative and qualitative features provided.
#
# #### Problem Description
# Forecasting is an important approach to take an optimal decision and implement appropriate action plans. A major non-life insurance company wants to evaluate customer life time value based on each customer’s demographics and policy information including claim details. The CLV is a profitability metric in terms of a value placed by the company on each customer and can be conceived in two dimensions: the customer`s present Value and potential future Value.
#
# You are expected to create an analytical and modelling framework to predict the life time value of each customer based on the quantitative and qualitative features provided in the dataset and also cluster the train dataset to understand behaviour of each segment.

# %% [markdown]
# # customer_life_time_value
# What is customer lifetime value (CLV)?
# Customer lifetime value is the total amount of money a customer is expected to spend with your business, or on your products, during the lifetime of an average business relationship.

# %%
#import required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = (10,8) #inbuilt figure size

# %%
#loading data
train_data = pd.read_csv("train-1574429526318.csv")
test_data = pd.read_csv("test-1574429501088.csv")

# %% [markdown]
# ### Explotary Data Analysis:

# %%
# To get the top 5 records of train
train_data.head()
# Out:
#    CustomerID  Customer.Lifetime.Value Coverage             Education  \
# 0        5917              7824.372789    Basic              Bachelor
# 1        2057              8005.964669    Basic               College
# 2        4119              8646.504109    Basic  High School or Below
# 3        1801              9294.088719    Basic               College
# 4        9618              5595.971365    Basic              Bachelor
#
#   EmploymentStatus Gender Income Location.Geo Location.Code Marital.Status  \
# 0       Unemployed      F      0    17.7,77.7         Urban        Married
# 1         Employed      M  63357    28.8,76.6      Suburban        Married
# 2         Employed      F  64125    21.6,88.4         Urban        Married
# 3         Employed      M  67544      19,72.5      Suburban        Married
# 4          Retired      F  19651    19.1,74.7      Suburban        Married
#
#    ...  Months.Since.Policy.Inception  Number.of.Open.Complaints  \
# 0  ...                             33                        NaN
# 1  ...                             42                        0.0
# 2  ...                             44                        0.0
# 3  ...                             15                        NaN
# 4  ...                             68                        0.0
#
#    Number.of.Policies     Policy.Type        Policy Renew.Offer.Type  \
# 0                 2.0   Personal Auto   Personal L2           Offer2
# 1                 5.0   Personal Auto   Personal L2           Offer2
# 2                 3.0   Personal Auto   Personal L1           Offer2
# 3                 3.0  Corporate Auto  Corporate L3           Offer1
# 4                 5.0   Personal Auto   Personal L1           Offer2
#
#   Sales.Channel Total.Claim.Amount  Vehicle.Class  Vehicle.Size
# 0        Branch         267.214383  Four-Door Car           2.0
# 1         Agent         565.508572            SUV           2.0
# 2        Branch         369.818708            SUV           1.0
# 3        Branch         556.800000            SUV           3.0
# 4           Web         345.600000   Two-Door Car           3.0
#
# [5 rows x 22 columns]

# %%
# To get the top 5 records of test
test_data.head()
# Out:
#    CustomerID  Coverage Education EmploymentStatus Gender   Income  \
# 0          17     Basic  Bachelor         Employed      M  43836.0
# 1          19  Extended   College         Employed      F  28812.0
# 2          29   Premium    Master         Employed      M  77026.0
# 3          34     Basic  Bachelor         Employed      F  24599.0
# 4          37  Extended  Bachelor         Disabled      F  13789.0
#
#   Location.Geo Location.Code Marital.Status  Monthly.Premium.Auto  ...  \
# 0    12.6,79.4         Rural         Single                  73.0  ...
# 1    17.3,78.4         Urban        Married                  93.0  ...
# 2    18.4,73.5         Urban        Married                 110.0  ...
# 3    17.1,78.2         Rural        Married                  64.0  ...
# 4      13,80.1      Suburban       Divorced                  79.0  ...
#
#    Months.Since.Policy.Inception  Number.of.Open.Complaints  \
# 0                             44                          0
# 1                              7                          0
# 2                             82                          2
# 3                             50                          1
# 4                             49                          0
#
#    Number.of.Policies     Policy.Type        Policy Renew.Offer.Type  \
# 0                   1   Personal Auto   Personal L1           Offer1
# 1                   8    Special Auto    Special L2           Offer2
# 2                   3  Corporate Auto  Corporate L1           Offer2
# 3                   2  Corporate Auto  Corporate L2           Offer2
# 4                   1   Personal Auto   Personal L3           Offer4
#
#   Sales.Channel Total.Claim.Amount  Vehicle.Class Vehicle.Size
# 0         Agent         138.130879  Four-Door Car      Medsize
# 1        Branch         425.527834  Four-Door Car      Medsize
# 2         Agent         472.029737  Four-Door Car      Medsize
# 3        Branch          42.920271  Four-Door Car      Medsize
# 4   Call Center         379.200000  Four-Door Car      Medsize
#
# [5 rows x 21 columns]

# %%
# describe gives the summary statstics of train data
train_data.describe(include ='all')
# Out:
#           CustomerID  Customer.Lifetime.Value Coverage Education  \
# count    9806.000000              9806.000000     8881      9677
# unique           NaN                      NaN        3         5
# top              NaN                      NaN    Basic  Bachelor
# freq             NaN                      NaN     5361      2934
# mean     5778.381807              7998.047015      NaN       NaN
# std      3343.286093              6848.055899      NaN       NaN
# min         1.000000              1898.007675      NaN       NaN
# 25%      2879.250000              4013.949039      NaN       NaN
# 50%      5783.000000              5780.182197      NaN       NaN
# 75%      8678.750000              8960.280213      NaN       NaN
# max     11573.000000             83325.381190      NaN       NaN
#
#        EmploymentStatus Gender Income Location.Geo Location.Code  \
# count              9688   9677   9806         9806          9687
# unique                5      2   4622         2840             3
# top            Employed      F      0        NA,NA      Suburban
# freq               6020   4985   2461          119          6204
# mean                NaN    NaN    NaN          NaN           NaN
# std                 NaN    NaN    NaN          NaN           NaN
# min                 NaN    NaN    NaN          NaN           NaN
# 25%                 NaN    NaN    NaN          NaN           NaN
# 50%                 NaN    NaN    NaN          NaN           NaN
# 75%                 NaN    NaN    NaN          NaN           NaN
# max                 NaN    NaN    NaN          NaN           NaN
#
#        Marital.Status  ...  Months.Since.Policy.Inception  \
# count            9677  ...                    9806.000000
# unique              3  ...                            NaN
# top           Married  ...                            NaN
# freq             5643  ...                            NaN
# mean              NaN  ...                      48.165001
# std               NaN  ...                      27.963630
# min               NaN  ...                       0.000000
# 25%               NaN  ...                      24.000000
# 50%               NaN  ...                      48.000000
# 75%               NaN  ...                      71.750000
# max               NaN  ...                      99.000000
#
#         Number.of.Open.Complaints  Number.of.Policies    Policy.Type  \
# count                 8988.000000         9685.000000           8915
# unique                        NaN                 NaN              3
# top                           NaN                 NaN  Personal Auto
# freq                          NaN                 NaN           6620
# mean                     0.379172            2.960351            NaN
# std                      0.896427            2.389801            NaN
# min                      0.000000            1.000000            NaN
# 25%                      0.000000            1.000000            NaN
# 50%                      0.000000            2.000000            NaN
# 75%                      0.000000            4.000000            NaN
# max                      5.000000            9.000000            NaN
#
#              Policy Renew.Offer.Type Sales.Channel Total.Claim.Amount  \
# count          9685             9678          9678        9806.000000
# unique            9                4             4                NaN
# top     Personal L3           Offer1         Agent                NaN
# freq           3637             3975          3670                NaN
# mean            NaN              NaN           NaN         438.266734
# std             NaN              NaN           NaN         293.502301
# min             NaN              NaN           NaN           0.099007
# 25%             NaN              NaN           NaN         280.352767
# 50%             NaN              NaN           NaN         384.007015
# 75%             NaN              NaN           NaN         553.540973
# max             NaN              NaN           NaN        2893.239678
#
#         Vehicle.Class  Vehicle.Size
# count            9680   9680.000000
# unique              6           NaN
# top     Four-Door Car           NaN
# freq             4869           NaN
# mean              NaN      2.089773
# std               NaN      0.538524
# min               NaN      1.000000
# 25%               NaN      2.000000
# 50%               NaN      2.000000
# 75%               NaN      2.000000
# max               NaN      3.000000
#
# [11 rows x 22 columns]

# %%
# To get the dimensions of train data
train_data.shape
# Out:
# (9806, 22)

# %%
# To get the dimensions of test data
test_data.shape
# Out:
# (1767, 21)

# %%
#removing duplicates from train data
train_data.drop_duplicates(keep='first', inplace=True)
train_data.shape
# Out:
# (9806, 22)

# %%
#removing duplicates from test data
test_data.drop_duplicates(keep='first', inplace=True)
test_data.shape
# Out:
# (1767, 21)

# %%
##checking the data types, non null count of train data
train_data.dtypes
# Out:
# CustomerID                         int64
# Customer.Lifetime.Value          float64
# Coverage                          object
# Education                         object
# EmploymentStatus                  object
# Gender                            object
# Income                            object
# Location.Geo                      object
# Location.Code                     object
# Marital.Status                    object
# Monthly.Premium.Auto             float64
# Months.Since.Last.Claim            int64
# Months.Since.Policy.Inception      int64
# Number.of.Open.Complaints        float64
# Number.of.Policies               float64
# Policy.Type                       object
# Policy                            object
# Renew.Offer.Type                  object
# Sales.Channel                     object
# Total.Claim.Amount               float64
# Vehicle.Class                     object
# Vehicle.Size                     float64
# dtype: object

# %% [markdown]
# Income is float but here it is showing in object because there are ? in some rows. let's try to resolve this

# %%
# replacing ? in income column with NaN
train_data['Income'] = train_data['Income'].replace('?', np.NaN)

# %%
train_data['Income']=train_data['Income'].astype('float64')

# %%
##checking the data types, non null count of train data
train_data.dtypes
# Out:
# CustomerID                         int64
# Customer.Lifetime.Value          float64
# Coverage                          object
# Education                         object
# EmploymentStatus                  object
# Gender                            object
# Income                           float64
# Location.Geo                      object
# Location.Code                     object
# Marital.Status                    object
# Monthly.Premium.Auto             float64
# Months.Since.Last.Claim            int64
# Months.Since.Policy.Inception      int64
# Number.of.Open.Complaints        float64
# Number.of.Policies               float64
# Policy.Type                       object
# Policy                            object
# Renew.Offer.Type                  object
# Sales.Channel                     object
# Total.Claim.Amount               float64
# Vehicle.Class                     object
# Vehicle.Size                     float64
# dtype: object

# %%
#checking the data types, non null count of test data
test_data.dtypes
# Out:
# CustomerID                         int64
# Coverage                          object
# Education                         object
# EmploymentStatus                  object
# Gender                            object
# Income                           float64
# Location.Geo                      object
# Location.Code                     object
# Marital.Status                    object
# Monthly.Premium.Auto             float64
# Months.Since.Last.Claim            int64
# Months.Since.Policy.Inception      int64
# Number.of.Open.Complaints          int64
# Number.of.Policies                 int64
# Policy.Type                       object
# Policy                            object
# Renew.Offer.Type                  object
# Sales.Channel                     object
# Total.Claim.Amount               float64
# Vehicle.Class                     object
# Vehicle.Size                      object
# dtype: object

# %%
#checking any unique values are there in train data
train_data.nunique()
# Out:
# CustomerID                       9806
# Customer.Lifetime.Value          6477
# Coverage                            3
# Education                           5
# EmploymentStatus                    5
# Gender                              2
# Income                           4621
# Location.Geo                     2840
# Location.Code                       3
# Marital.Status                      3
# Monthly.Premium.Auto              191
# Months.Since.Last.Claim            36
# Months.Since.Policy.Inception     100
# Number.of.Open.Complaints           6
# Number.of.Policies                  9
# Policy.Type                         3
# Policy                              9
# Renew.Offer.Type                    4
# Sales.Channel                       4
# Total.Claim.Amount               4125
# Vehicle.Class                       6
# Vehicle.Size                        3
# dtype: int64

# %%
#checking sum of null values from train data
train_data.isnull().sum()
# Out:
# CustomerID                         0
# Customer.Lifetime.Value            0
# Coverage                         925
# Education                        129
# EmploymentStatus                 118
# Gender                           129
# Income                           118
# Location.Geo                       0
# Location.Code                    119
# Marital.Status                   129
# Monthly.Premium.Auto             794
# Months.Since.Last.Claim            0
# Months.Since.Policy.Inception      0
# Number.of.Open.Complaints        818
# Number.of.Policies               121
# Policy.Type                      891
# Policy                           121
# Renew.Offer.Type                 128
# Sales.Channel                    128
# Total.Claim.Amount                 0
# Vehicle.Class                    126
# Vehicle.Size                     126
# dtype: int64

# %%
#checking sum of null values from test data
test_data.isnull().sum()
# Out:
# CustomerID                         0
# Coverage                           0
# Education                          0
# EmploymentStatus                   0
# Gender                             0
# Income                           239
# Location.Geo                       0
# Location.Code                      0
# Marital.Status                     0
# Monthly.Premium.Auto              72
# Months.Since.Last.Claim            0
# Months.Since.Policy.Inception      0
# Number.of.Open.Complaints          0
# Number.of.Policies                 0
# Policy.Type                       42
# Policy                             0
# Renew.Offer.Type                   0
# Sales.Channel                      0
# Total.Claim.Amount                 0
# Vehicle.Class                      0
# Vehicle.Size                       0
# dtype: int64

# %%
cols = train_data.columns
cols
# Out:
# Index(['CustomerID', 'Customer.Lifetime.Value', 'Coverage', 'Education',
#        'EmploymentStatus', 'Gender', 'Income', 'Location.Geo', 'Location.Code',
#        'Marital.Status', 'Monthly.Premium.Auto', 'Months.Since.Last.Claim',
#        'Months.Since.Policy.Inception', 'Number.of.Open.Complaints',
#        'Number.of.Policies', 'Policy.Type', 'Policy', 'Renew.Offer.Type',
#        'Sales.Channel', 'Total.Claim.Amount', 'Vehicle.Class', 'Vehicle.Size'],
#       dtype='object')

# %%
_ =train_data.hist()
plt.tight_layout()
plt.figure(figsize=(30,30))
plt.show()

# %%
#checking value counts present in each column
for i in train_data.columns:
    print(i)
    print(train_data[i].value_counts(normalize=True)*100)
    print(f"unique values of {i}-------->{len(train_data[i].unique())}")
    print("<------------------------------->")
# Out:
# CustomerID
# 5917     0.010198
# 2315     0.010198
# 8440     0.010198
# 7806     0.010198
# 11064    0.010198
#            ...
# 3034     0.010198
# 2637     0.010198
# 9334     0.010198
# 8102     0.010198
# 11323    0.010198
# Name: CustomerID, Length: 9806, dtype: float64
# unique values of CustomerID-------->9806
# <------------------------------->
# Customer.Lifetime.Value
# 6689.022728     0.132572
# 10656.881950    0.112176
# 10208.927610    0.101978
# 6521.368813     0.101978
# 7285.030983     0.101978
#                   ...
# 15083.784980    0.010198
# 9082.833891     0.010198
# 6245.443568     0.010198
# 8556.418397     0.010198
# 8583.272854     0.010198
# Name: Customer.Lifetime.Value, Length: 6477, dtype: float64
# unique values of Customer.Lifetime.Value-------->6477
# <------------------------------->
# Coverage
# Basic       60.364824
# Extended    30.368202
# Premium      9.266974
# Name: Coverage, dtype: float64
# unique values of Coverage-------->4
# <------------------------------->
# Education
# Bachelor                30.319314
# College                 29.306603
# High School or Below    28.893252
# Master                   7.843340
# Doctor                   3.637491
# Name: Education, dtype: float64
# unique values of Education-------->6
# <------------------------------->
# EmploymentStatus
# Employed         62.138728
# Unemployed       25.402560
# Medical Leave     5.068126
# Disabled          4.428159
# Retired           2.962428
# Name: EmploymentStatus, dtype: float64
# unique values of EmploymentStatus-------->6
# <------------------------------->
# Gender
# F    51.513899
# M    48.486101
# Name: Gender, dtype: float64
# unique values of Gender-------->3
# <------------------------------->
# Income
# 0.0        25.402560
# 20396.0     0.113543
# 11828.0     0.113543
# 28142.0     0.113543
# 22520.0     0.103220
#              ...
# 43704.0     0.010322
# 23222.0     0.010322
# 77882.0     0.010322
# 95579.0     0.010322
# 18017.0     0.010322
# Name: Income, Length: 4621, dtype: float64
# unique values of Income-------->4622
# <------------------------------->
# Location.Geo
# NA,NA        1.213543
# 19.2,72.4    0.265144
# 18.9,72.6    0.265144
# 18.9,72.7    0.224352
# 17.2,78.5    0.214155
#                ...
# 13.4,78.8    0.010198
# 20,73.3      0.010198
# 29.8,78.7    0.010198
# 21.9,88.7    0.010198
# 28.3,77.6    0.010198
# Name: Location.Geo, Length: 2840, dtype: float64
# unique values of Location.Geo-------->2840
# <------------------------------->
# Location.Code
# Suburban    64.044596
# Rural       18.684835
# Urban       17.270569
# Name: Location.Code, dtype: float64
# unique values of Location.Code-------->4
# <------------------------------->
# Marital.Status
# Married     58.313527
# Single      26.878165
# Divorced    14.808308
# Name: Marital.Status, dtype: float64
# unique values of Marital.Status-------->4
# <------------------------------->
# Monthly.Premium.Auto
# 65.0     3.861518
# 71.0     3.417665
# 73.0     3.306702
# 66.0     3.195739
# 67.0     3.173546
#            ...
# 142.0    0.011096
# 206.0    0.011096
# 238.0    0.011096
# 232.0    0.011096
# 286.0    0.011096
# Name: Monthly.Premium.Auto, Length: 191, dtype: float64
# unique values of Monthly.Premium.Auto-------->192
# <------------------------------->
# Months.Since.Last.Claim
# 3     4.130124
# 2     3.956761
# 7     3.864981
# 6     3.773200
# 1     3.630430
# 10    3.579441
# 4     3.559045
# 5     3.416276
# 15    3.232715
# 16    3.222517
# 11    3.212319
# 12    3.120538
# 14    3.028758
# 0     3.018560
# 17    2.998164
# 8     2.947175
# 13    2.865592
# 21    2.682031
# 20    2.671834
# 9     2.671834
# 23    2.620844
# 19    2.600449
# 18    2.580053
# 22    2.508668
# 25    2.406690
# 24    2.304711
# 29    2.263920
# 31    2.253722
# 26    2.202733
# 28    2.121150
# 27    2.080359
# 33    1.937589
# 34    1.845809
# 30    1.805017
# 35    1.488884
# 32    1.397104
# Name: Months.Since.Last.Claim, dtype: float64
# unique values of Months.Since.Last.Claim-------->36
# <------------------------------->
# Months.Since.Policy.Inception
# 59    1.590863
# 61    1.458291
# 50    1.407302
# 43    1.356312
# 56    1.295125
#         ...
# 96    0.734244
# 94    0.724047
# 82    0.591475
# 97    0.581277
# 98    0.530288
# Name: Months.Since.Policy.Inception, Length: 100, dtype: float64
# unique values of Months.Since.Policy.Inception-------->100
# <------------------------------->
# Number.of.Open.Complaints
# 0.0    79.327993
# 1.0    11.337339
# 2.0     4.116600
# 3.0     3.081887
# 4.0     1.579884
# 5.0     0.556297
# Name: Number.of.Open.Complaints, dtype: float64
# unique values of Number.of.Open.Complaints-------->7
# <------------------------------->
# Number.of.Policies
# 1.0    35.715023
# 2.0    25.121322
# 3.0    12.803304
# 7.0     4.749613
# 9.0     4.605059
# 5.0     4.481156
# 4.0     4.429530
# 8.0     4.140423
# 6.0     3.954569
# Name: Number.of.Policies, dtype: float64
# unique values of Number.of.Policies-------->10
# <------------------------------->
# Policy.Type
# Personal Auto     74.256870
# Corporate Auto    21.536736
# Special Auto       4.206394
# Name: Policy.Type, dtype: float64
# unique values of Policy.Type-------->4
# <------------------------------->
# Policy
# Personal L3     37.552917
# Personal L2     23.448632
# Personal L1     13.154362
# Corporate L3    11.017037
# Corporate L2     6.381002
# Corporate L1     4.233351
# Special L2       1.951471
# Special L3       1.600413
# Special L1       0.660816
# Name: Policy, dtype: float64
# unique values of Policy-------->10
# <------------------------------->
# Renew.Offer.Type
# Offer1    41.072536
# Offer2    31.866088
# Offer3    15.912379
# Offer4    11.148998
# Name: Renew.Offer.Type, dtype: float64
# unique values of Renew.Offer.Type-------->5
# <------------------------------->
# Sales.Channel
# Agent          37.921058
# Branch         28.487291
# Call Center    19.239512
# Web            14.352139
# Name: Sales.Channel, dtype: float64
# unique values of Sales.Channel-------->5
# <------------------------------->
# Total.Claim.Amount
# 312.000000    1.458291
# 350.400000    1.203345
# 316.800000    1.142158
# 292.800000    1.121762
# 331.200000    1.080971
#                 ...
# 773.470977    0.010198
# 125.961938    0.010198
# 472.599683    0.010198
# 346.319404    0.010198
# 441.992043    0.010198
# Name: Total.Claim.Amount, Length: 4125, dtype: float64
# unique values of Total.Claim.Amount-------->4125
# <------------------------------->
# Vehicle.Class
# Four-Door Car    50.299587
# Two-Door Car     20.919421
# SUV              19.617769
# Sports Car        5.340909
# Luxury SUV        1.921488
# Luxury Car        1.900826
# Name: Vehicle.Class, dtype: float64
# unique values of Vehicle.Class-------->7
# <------------------------------->
# Vehicle.Size
# 2.0    70.196281
# 3.0    19.390496
# 1.0    10.413223
# Name: Vehicle.Size, dtype: float64
# unique values of Vehicle.Size-------->4
# <------------------------------->

# %%
df_cat1 = train_data.select_dtypes(include = ['object'])

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Pie - charts
# </b></div>

# %%
fig, axes = plt.subplots(round(len(df_cat1.columns) / 4), 4, figsize=(20, 15))

for i, ax in enumerate(fig.axes):
    if i < len(df_cat1.columns):
        train_data[df_cat1.columns[i]].value_counts().plot.pie(autopct = '%1.1f%%',ax = ax)
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
        ax.set_title(df_cat1.columns[i])

fig.tight_layout()

# %% [markdown]
# The pie charts show the percentage of customers in each category of the categorical variables

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Bar plots
# </b></div>

# %%
fig, axes = plt.subplots(round(len(df_cat1.columns) / 4), 4, figsize=(20, 20))

for i, ax in enumerate(fig.axes):
    if i < len(df_cat1.columns):
        sns.barplot(x = train_data[df_cat1.columns[i]],y = train_data['Customer.Lifetime.Value'],data = train_data, ax = ax )
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)

fig.tight_layout()

# %% [markdown]
# The Bar charts show the average customer life time value of customers in each category of the categorical variables

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Histograms-KDE
# </b></div>

# %%
sns.histplot(train_data["Customer.Lifetime.Value"],kde=True,bins=8)
plt.show()

# %%
sns.histplot(train_data['Income'],kde=True,bins=8)
plt.show()

# %%
sns.histplot(train_data['Monthly.Premium.Auto'],kde=True,bins=8)
plt.show()

# %%
sns.histplot(train_data['Number.of.Open.Complaints'],kde=True,bins=8)
plt.show()

# %%
train_data.plot.kde(subplots = True, figsize = (30, 30),
                       layout = (4,4), color = "deepskyblue");

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Correlation between Independent features and Dependent Features
# </b></div>

# %%
df_num_corr = train_data.corr()['Customer.Lifetime.Value'].sort_values(ascending=False)
df_num_corr
# Out:
# Customer.Lifetime.Value          1.000000
# Monthly.Premium.Auto             0.400453
# Total.Claim.Amount               0.221572
# Income                           0.022937
# Number.of.Policies               0.022227
# Vehicle.Size                     0.019749
# Months.Since.Policy.Inception    0.011508
# Months.Since.Last.Claim          0.007151
# CustomerID                      -0.008037
# Number.of.Open.Complaints       -0.042008
# Name: Customer.Lifetime.Value, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#  Heat map
# </b></div>

# %%
# creating mask
mask = np.triu(np.ones_like(train_data.corr()))
 
# plotting a triangle correlation heatmap
dataplot = sns.heatmap(train_data.corr(), cmap="YlGnBu", annot=True, mask=mask)
 
# displaying heatmap
plt.show()

# %% [markdown]
# 1-None of the features are strongly correlated with the target variable (Customer Life time Value).
#
# 2.The highest correlation can be seen between two independent variables - Monthly premium auto and total claim amount, which is equal to 0.63.

# %%
test_data1 = test_data.copy()

# %%
xtr = train_data.drop(["CustomerID","Location.Geo"],axis=1)
xte = test_data.drop(["CustomerID","Location.Geo"],axis=1)

# %%
# Scatterplot to check the relation between each pair of numerical columns
pd.plotting.scatter_matrix(xtr, figsize=(16, 16), diagonal='kde')
plt.show()

# %%
ytr = train_data[["Customer.Lifetime.Value"]]

# %%
#vehicle size in train data is in float and vehicle size test data is in object
xtr["Vehicle.Size"].value_counts()
# Out:
# 2.0    6795
# 3.0    1877
# 1.0    1008
# Name: Vehicle.Size, dtype: int64

# %%
xte["Vehicle.Size"].value_counts()
# Out:
# Medsize    1252
# Small       343
# Large       172
# Name: Vehicle.Size, dtype: int64

# %%
xte = xte.replace({'Vehicle.Size': {"Large" : 1.0, "Medsize" : 2.0, "Small" : 3.0}})
xte["Vehicle.Size"].value_counts()
# Out:
# 2.0    1252
# 3.0     343
# 1.0     172
# Name: Vehicle.Size, dtype: int64

# %%
xtr = train_data.drop(["Customer.Lifetime.Value","CustomerID","Location.Geo"],axis=1)

# %%
cat_cols = [col for col in xtr.columns if xtr.dtypes[col]=="object"]
cat_cols
# Out:
# ['Coverage',
#  'Education',
#  'EmploymentStatus',
#  'Gender',
#  'Location.Code',
#  'Marital.Status',
#  'Policy.Type',
#  'Policy',
#  'Renew.Offer.Type',
#  'Sales.Channel',
#  'Vehicle.Class']

# %%
num_cols = [col for col in xtr.columns if xtr.dtypes[col] !="object"]
num_cols
# Out:
# ['Income',
#  'Monthly.Premium.Auto',
#  'Months.Since.Last.Claim',
#  'Months.Since.Policy.Inception',
#  'Number.of.Open.Complaints',
#  'Number.of.Policies',
#  'Total.Claim.Amount',
#  'Vehicle.Size']

# %%
xtr_cat = xtr[cat_cols]
xtr_num = xtr[num_cols]
xte_cat = xte[cat_cols]
xte_num = xte[num_cols]

# %% [markdown]
# ### Null value imputation

# %%
from sklearn.impute import SimpleImputer
cat_impu=SimpleImputer(missing_values=np.nan,strategy="most_frequent")
num_impu=SimpleImputer(missing_values=np.nan,strategy ="median")
xtr_cat=pd.DataFrame(cat_impu.fit_transform(xtr_cat),columns=cat_cols)
xtr_num=pd.DataFrame(num_impu.fit_transform(xtr_num),columns=num_cols)
xte_cat=pd.DataFrame(cat_impu.fit_transform(xte_cat),columns=cat_cols)
xte_num=pd.DataFrame(num_impu.fit_transform(xte_num),columns=num_cols)

# %%
# Function to convert all object columns to categorical
xtr_cat[cat_cols]=xtr_cat[cat_cols].astype("category")
xte_cat[cat_cols]=xte_cat[cat_cols].astype("category")

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Dummifing categorical features into numerical using Label encoder
# </b></div>

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
for col in cat_cols:
    xtr_cat[col]=encoder.fit_transform(xtr_cat[col])
    xte_cat[col]=encoder.fit_transform(xte_cat[col])

# %%
xtr_cat.head()
# Out:
#    Coverage  Education  EmploymentStatus  Gender  Location.Code  \
# 0         0          0                 4       0              2
# 1         0          1                 1       1              1
# 2         0          3                 1       0              2
# 3         0          1                 1       1              1
# 4         0          0                 3       0              1
#
#    Marital.Status  Policy.Type  Policy  Renew.Offer.Type  Sales.Channel  \
# 0               1            1       4                 1              1
# 1               1            1       4                 1              0
# 2               1            1       3                 1              1
# 3               1            0       2                 0              1
# 4               1            1       3                 1              3
#
#    Vehicle.Class
# 0              0
# 1              3
# 2              3
# 3              3
# 4              5

# %%
train_data.shape
# Out:
# (9806, 22)

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   concat the dummfiying values,scaling values
# </b></div>

# %%
xtr=pd.concat([xtr_num,xtr_cat],axis=1)

# %%
xte=pd.concat([xte_num,xte_cat],axis=1)

# %%
columnsxtr = xtr.columns
columnsxtr
# Out:
# Index(['Income', 'Monthly.Premium.Auto', 'Months.Since.Last.Claim',
#        'Months.Since.Policy.Inception', 'Number.of.Open.Complaints',
#        'Number.of.Policies', 'Total.Claim.Amount', 'Vehicle.Size', 'Coverage',
#        'Education', 'EmploymentStatus', 'Gender', 'Location.Code',
#        'Marital.Status', 'Policy.Type', 'Policy', 'Renew.Offer.Type',
#        'Sales.Channel', 'Vehicle.Class'],
#       dtype='object')

# %%
columnsxte = xte.columns
columnsxte
# Out:
# Index(['Income', 'Monthly.Premium.Auto', 'Months.Since.Last.Claim',
#        'Months.Since.Policy.Inception', 'Number.of.Open.Complaints',
#        'Number.of.Policies', 'Total.Claim.Amount', 'Vehicle.Size', 'Coverage',
#        'Education', 'EmploymentStatus', 'Gender', 'Location.Code',
#        'Marital.Status', 'Policy.Type', 'Policy', 'Renew.Offer.Type',
#        'Sales.Channel', 'Vehicle.Class'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   scaling the data using normalization
# </b></div>

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
scale.fit(xtr)
# Out:
# MinMaxScaler()

# %%
xtr = pd.DataFrame(scale.transform(xtr),columns=columnsxtr)

# %%
xtr.isnull().sum()
# Out:
# Income                           0
# Monthly.Premium.Auto             0
# Months.Since.Last.Claim          0
# Months.Since.Policy.Inception    0
# Number.of.Open.Complaints        0
# Number.of.Policies               0
# Total.Claim.Amount               0
# Vehicle.Size                     0
# Coverage                         0
# Education                        0
# EmploymentStatus                 0
# Gender                           0
# Location.Code                    0
# Marital.Status                   0
# Policy.Type                      0
# Policy                           0
# Renew.Offer.Type                 0
# Sales.Channel                    0
# Vehicle.Class                    0
# dtype: int64

# %%
xte.isnull().sum()
# Out:
# Income                           0
# Monthly.Premium.Auto             0
# Months.Since.Last.Claim          0
# Months.Since.Policy.Inception    0
# Number.of.Open.Complaints        0
# Number.of.Policies               0
# Total.Claim.Amount               0
# Vehicle.Size                     0
# Coverage                         0
# Education                        0
# EmploymentStatus                 0
# Gender                           0
# Location.Code                    0
# Marital.Status                   0
# Policy.Type                      0
# Policy                           0
# Renew.Offer.Type                 0
# Sales.Channel                    0
# Vehicle.Class                    0
# dtype: int64

# %%
xte.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1767 entries, 0 to 1766
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Income                         1767 non-null   float64
#  1   Monthly.Premium.Auto           1767 non-null   float64
#  2   Months.Since.Last.Claim        1767 non-null   float64
#  3   Months.Since.Policy.Inception  1767 non-null   float64
#  4   Number.of.Open.Complaints      1767 non-null   float64
#  5   Number.of.Policies             1767 non-null   float64
#  6   Total.Claim.Amount             1767 non-null   float64
#  7   Vehicle.Size                   1767 non-null   float64
#  8   Coverage                       1767 non-null   int32
#  9   Education                      1767 non-null   int32
#  10  EmploymentStatus               1767 non-null   int32
#  11  Gender                         1767 non-null   int32
#  12  Location.Code                  1767 non-null   int32
#  13  Marital.Status                 1767 non-null   int32
#  14  Policy.Type                    1767 non-null   int32
#  15  Policy                         1767 non-null   int32
#  16  Renew.Offer.Type               1767 non-null   int32
#  17  Sales.Channel                  1767 non-null   int32
#  18  Vehicle.Class                  1767 non-null   int32
# dtypes: float64(8), int32(11)
# memory usage: 186.5 KB

# %%
xte = pd.DataFrame(scale.transform(xte),columns=columnsxte)

# %%
xte.head()
# Out:
#      Income  Monthly.Premium.Auto  Months.Since.Last.Claim  \
# 0  0.438443              0.050847                 0.342857
# 1  0.288175              0.135593                 0.485714
# 2  0.770406              0.207627                 0.257143
# 3  0.246037              0.012712                 0.342857
# 4  0.137916              0.076271                 0.228571
#
#    Months.Since.Policy.Inception  Number.of.Open.Complaints  \
# 0                       0.444444                        0.0
# 1                       0.070707                        0.0
# 2                       0.828283                        0.4
# 3                       0.505051                        0.2
# 4                       0.494949                        0.0
#
#    Number.of.Policies  Total.Claim.Amount  Vehicle.Size  Coverage  Education  \
# 0               0.000            0.047710           0.5       0.0       0.00
# 1               0.875            0.147047           0.5       0.5       0.25
# 2               0.250            0.163121           0.5       1.0       1.00
# 3               0.125            0.014801           0.5       0.0       0.00
# 4               0.000            0.131034           0.5       0.5       0.00
#
#    EmploymentStatus  Gender  Location.Code  Marital.Status  Policy.Type  \
# 0              0.25     1.0            0.0             1.0          0.5
# 1              0.25     0.0            1.0             0.5          1.0
# 2              0.25     1.0            1.0             0.5          0.0
# 3              0.25     0.0            0.0             0.5          0.0
# 4              0.00     0.0            0.5             0.0          0.5
#
#    Policy  Renew.Offer.Type  Sales.Channel  Vehicle.Class
# 0   0.375          0.000000       0.000000            0.0
# 1   0.875          0.333333       0.333333            0.0
# 2   0.000          0.333333       0.000000            0.0
# 3   0.125          0.333333       0.333333            0.0
# 4   0.625          1.000000       0.666667            0.0

# %%
mask = np.triu(np.ones_like(xte.corr()))
 
# plotting a triangle correlation heatmap
dataplot = sns.heatmap(xte.corr(), cmap="YlGnBu", annot=True, mask=mask)
plt.figure(figsize=(14,8))
# displaying heatmap
plt.show()

# %%
import matplotlib.pyplot as plt
for col in xtr.columns:
    print("for",col)
    plt.scatter(xtr[col],ytr)
    plt.show()
# Out:
# for Income
# for Monthly.Premium.Auto
# for Months.Since.Last.Claim
# for Months.Since.Policy.Inception
# for Number.of.Open.Complaints
# for Number.of.Policies
# for Total.Claim.Amount
# for Vehicle.Size
# for Coverage
# for Education
# for EmploymentStatus
# for Gender
# for Location.Code
# for Marital.Status
# for Policy.Type
# for Policy
# for Renew.Offer.Type
# for Sales.Channel
# for Vehicle.Class

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Splitting our data
# </b></div>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(xtr,ytr,test_size=0.25,random_state=142)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7354, 19)
# (2452, 19)
# (7354, 1)
# (2452, 1)

# %% [markdown]
# ### Model Building

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Linear Regression
# </b></div>

# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
train_pred=reg.predict(x_train)
test_pred = reg.predict(x_test)
print('RMSE LinearRegression on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('RMSE LinearRegression on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# RMSE LinearRegression on train :  6276.785352039797
# RMSE LinearRegression on test :  6306.356508999642

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Ridge Regression
# </b></div>

# %%
from sklearn.linear_model import Ridge, Lasso
#Ridge Regression Model
ridgeReg = Ridge(alpha=10)

ridgeReg.fit(x_train,y_train)

train_pred=ridgeReg.predict(x_train)
test_pred = ridgeReg.predict(x_test)
print('Ridge Regression on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('Ridge Regression on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# Ridge Regression on train :  6280.141212501634
# Ridge Regression on test :  6306.505798597021

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Lasso Regression
# </b></div>

# %%
#Lasso regression model
lasso = Lasso(alpha = 10)
lasso.fit(x_train,y_train)
train_pred=lasso.predict(x_train)
test_pred = lasso.predict(x_test)
print('lasso Regression on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('lasso Regression on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# lasso Regression on train :  6279.063916423384
# lasso Regression on test :  6305.097604418806

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#   Random Forest Regressor
# </b></div>

# %%
from sklearn.ensemble import RandomForestRegressor

model_RFR = RandomForestRegressor(random_state=3,max_depth=9,min_samples_leaf=3)
model_RFR.fit(x_train, y_train)
train_pred=model_RFR.predict(x_train)
test_pred = model_RFR.predict(x_test)
print('RMSE RandomForestRegressor on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('RMSE RandomForestRegressor on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# RMSE RandomForestRegressor on train :  3190.291652414883
# RMSE RandomForestRegressor on test :  3922.0365102507767

# %%
#RandomSearchCV designed to find the best parameters to improve our model
from sklearn.model_selection import RandomizedSearchCV
rf_grid = RandomForestRegressor(random_state=4)
rf_param_grid = {"n_estimators" : [2,4,6,8,10,12,14,16,20,25],
                 "max_depth" : [5,7,9,11,13,15],
                 "min_samples_leaf" : [2,3,5,7,10]}
rf2=RandomizedSearchCV(rf_grid,rf_param_grid,cv=10,n_jobs=-1,n_iter=3000)
rf2.fit(x_train,y_train)
train_pred=rf2.predict(x_train)
test_pred = rf2.predict(x_test)
print('RMSE RandomizedSearchCV on train : ', np.sqrt(mean_squared_error(y_train, train_pred)))
print('RMSE RandomizedSearchCV on test : ', np.sqrt(mean_squared_error(y_test, test_pred)))
# Out:
# RMSE RandomizedSearchCV on train :  3088.210169157668
# RMSE RandomizedSearchCV on test :  3941.3918776155765

# %% [markdown]
# # Conclusion

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#    Tuned Random forest regressor gave the best results as compared to all the other algorithms we tried.
# </b></div>

# %% [markdown]
# # Lets work on test data

# %% [markdown]
# ### Predictions

# %%
Target = pd.DataFrame(rf2.predict(xte),columns=['Customer.Lifetime.Value'])

# %%
CustomerID=pd.DataFrame(test_data1.CustomerID)

# %%
pred=pd.concat([CustomerID,Target],axis=1)

# %%
pred.head()
# Out:
#    CustomerID  Customer.Lifetime.Value
# 0          17              2866.182533
# 1          19              7235.071578
# 2          29              8702.522588
# 3          34             10084.121099
# 4          37              3040.721646

# %%
pred.to_csv('Submission1rf22.csv',index=False)

# %%
submission=pd.read_csv("Submission1rf22.csv")

# %%
submission.head()
# Out:
#    CustomerID  Customer.Lifetime.Value
# 0          17              2866.182533
# 1          19              7235.071578
# 2          29              8702.522588
# 3          34             10084.121099
# 4          37              3040.721646

# %% [markdown]
# ### clustering

# %%
col=["Income"]

# %%
impu=SimpleImputer(missing_values=np.nan,strategy ="median")
train_data[["Income"]]=pd.DataFrame(impu.fit_transform(train_data[["Income"]]),columns=col)

# %%
X1= train_data[['Income','Customer.Lifetime.Value']].iloc[: , :].values

from sklearn.cluster import KMeans
wcss=[]
for k in range(1,11):
    kmeans = KMeans(n_clusters = k, init = "k-means++")
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)
plt.figure(figsize =( 12,6))
plt.grid()
plt.plot(range(1,11),wcss,linewidth=2,color="red",marker="8")
plt.xlabel("K Value")
plt.ylabel("WCSS")
plt.show()

# %%
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
# k is range of number of clusters.
visualizer = KElbowVisualizer(model, k=(2,10), timings= True)
visualizer.fit(X1)        # Fit data to visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans = KMeans(n_clusters=4)

label = kmeans.fit_predict(X1)

print(label)
# Out:
# [0 1 1 ... 3 3 2]

# %%
print(kmeans.cluster_centers_)
# Out:
# [[ 1177.36929308  7654.75663866]
#  [56229.46866607  8336.2075911 ]
#  [28745.35836066  8041.45009682]
#  [83557.00498339  8022.71286898]]

# %%
plt.scatter(X1[:,0],X1[:,1],c=kmeans.labels_,cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],color='black',s=200,marker='*')
plt.title('Clusters of Customers')
plt.xlabel('Income')
plt.ylabel('Customer life time value')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>
#  **Conclusion:**
#
# -For large number of data K-Means Clustering is always good.
#
# -It's easy to find the optimal no of clusters in K-Means because of elbow method.
#
#  (we can't find the optimal no of clusters accuratley by using dendogram for large number of data. hence, for large number of data Hierarchical clustering is not possible)
#      </b></div>
